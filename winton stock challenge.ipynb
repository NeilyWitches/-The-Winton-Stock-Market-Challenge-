# %%
import pandas as pd

# %%
file_path = r"C:\Users\drumm\Documents\kaggle\the-winton-stock-market-challenge\train.csv"
file_path2 = r"C:\Users\drumm\Documents\kaggle\the-winton-stock-market-challenge\test_2.csv"
file_path3 = r"C:\Users\drumm\Documents\kaggle\the-winton-stock-market-challenge\sample_submission_2.csv"
file_path4 = r"C:\Users\drumm\Documents\kaggle\the-winton-stock-market-challenge\submission.csv"

# %%
train_df = pd.read_csv(file_path)

# %%
test_df = pd.read_csv(file_path2)

# %%
sample_df = pd.read_csv(file_path3)

# %%
submission_df = pd.read_csv(file_path4)

# %%
y = train_df.loc[:, 'Ret_121':'Ret_PlusTwo']

# %%
X = train_df.loc[:, 'Feature_1':'Ret_120']

# %%
X.columns
# Out:
# Index(['Feature_1', 'Feature_2', 'Feature_3', 'Feature_4', 'Feature_5',
#        'Feature_6', 'Feature_7', 'Feature_8', 'Feature_9', 'Feature_10',
#        ...
#        'Ret_111', 'Ret_112', 'Ret_113', 'Ret_114', 'Ret_115', 'Ret_116',
#        'Ret_117', 'Ret_118', 'Ret_119', 'Ret_120'],
#       dtype='object', length=146)

# %%
X_test = test_df.loc[:, "Feature_1":'Ret_120']

# %%
from matplotlib import pyplot as pp
pp.plot(X.Feature_1,y.Ret_137)

# %%
corr_mat = train_df.corr()

# %%
import numpy as np
corr_mat_array = np.array(corr_mat)

# %%
for i in range(len(corr_mat_array)):
    for j in range(len(corr_mat_array)):
# Out:
#                        Id  Feature_1  Feature_2  Feature_3  Feature_4  \
# Id               1.000000   0.015359  -0.011236   0.000260   0.003502
# Feature_1        0.015359   1.000000  -0.101700  -0.019848   0.051001
# Feature_2       -0.011236  -0.101700   1.000000  -0.173150  -0.221787
# Feature_3        0.000260  -0.019848  -0.173150   1.000000   0.775212
# Feature_4        0.003502   0.051001  -0.221787   0.775212   1.000000
# Feature_5        0.002117  -0.037750   0.056375  -0.036618  -0.218070
# Feature_6        0.001613   0.052950  -0.090757   0.526035   0.507797
# Feature_7       -0.000771   0.010163  -0.002199   0.001326   0.009578
# Feature_8       -0.000914  -0.010223   0.007618  -0.003993  -0.007142
# Feature_9        0.003592  -0.061244  -0.095627   0.425604   0.449600
# Feature_10       0.005672  -0.334303   0.065810   0.035304   0.012427
# Feature_11      -0.000909   0.025696   0.127949  -0.937326  -0.630680
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(corr_mat)
# Out:
#                        Id     Feature_1  Feature_2  Feature_3  Feature_4  \
# Id               1.000000  1.535876e-02  -0.011236   0.000260   0.003502
# Feature_1        0.015359  1.000000e+00  -0.101700  -0.019848   0.051001
# Feature_2       -0.011236 -1.017002e-01   1.000000  -0.173150  -0.221787
# Feature_3        0.000260 -1.984794e-02  -0.173150   1.000000   0.775212
# Feature_4        0.003502  5.100091e-02  -0.221787   0.775212   1.000000
# Feature_5        0.002117 -3.774982e-02   0.056375  -0.036618  -0.218070
# Feature_6        0.001613  5.295020e-02  -0.090757   0.526035   0.507797
# Feature_7       -0.000771  1.016317e-02  -0.002199   0.001326   0.009578
# Feature_8       -0.000914 -1.022344e-02   0.007618  -0.003993  -0.007142
# Feature_9        0.003592 -6.124407e-02  -0.095627   0.425604   0.449600
# Feature_10       0.005672 -3.343026e-01   0.065810   0.035304   0.012427
# Feature_11      -0.000909  2.569596e-02   0.127949  -0.937326  -0.630680
# ...

# %%
import seaborn as sns
sns.heatmap(corr_mat,annot=True)

# %%
pp.plot(X.Ret_56,y.Ret_123)

# %%
ret56ret121 = pd.DataFrame({'ret56':X.Ret_56,'ret121':y.Ret_121})

# %%
ret56ret121.loc[ret56ret121['ret56'] >= 0.05]
# Out:
#           ret56   ret121
# 34486  0.233762  0.03469

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(xret56a.reshape(-1,1),y.Ret_121)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-70c2a98072f6> in <module>
#       1 from sklearn import linear_model
#       2 reg = linear_model.LinearRegression()
# ----> 3 reg.fit(xret56a.reshape(-1,1),y.Ret_121)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
for col in train_df.['Feature_1':'Ret_120']
# Out:
# 0.04897237207124069

# %%
cols_with_missing = [col for col in X.columns if X[col].isnull().any()]

# %%
X_plus = X.copy()
X_test_plus = X_test.copy()

# Make new columns indicating what will be imputed
for col in cols_with_missing:
    X_plus[col + '_was_missing'] = X_plus[col].isnull()
    X_test_plus[col + '_was_missing'] = X_test_plus[col].isnull()

# %%
from sklearn.impute import SimpleImputer

my_imputer = SimpleImputer()
imputed_X_plus = pd.DataFrame(my_imputer.fit_transform(X_plus))

# Imputation removed column names; put them back
imputed_X_plus.columns = X_plus.columns

# %%
imputed_X_test_plus = pd.DataFrame(my_imputer.transform(X_test_plus))

# %%
imputed_X_test_plus.columns = X_test_plus.columns

# %%
output = pd.DataFrame({'Id': sample_df.Id,
                      'Predicted': combined5})
output.to_csv('submission.csv', index=False)
